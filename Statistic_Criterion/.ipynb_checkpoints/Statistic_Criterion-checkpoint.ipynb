# %% [markdown]
# ## Purpose
#
# This notebook implements the DaNN.

# %%
import tensorflow as tf
import math
from keras.datasets import mnist
from keras.utils import to_categorical
from keras import layers
from keras import models
from keras.models import Model
from keras import backend as K
from keras.regularizers import Regularizer
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization, Activation, ZeroPadding2D, MaxPooling2D
from keras.layers.convolutional import UpSampling2D, Conv2D
import keras
import warnings
warnings.filterwarnings('ignore')
import cv2
import numpy as np
import h5py
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.

# %% [markdown]
# ## Data

# %%
# !git clone https://github.com/NuriaSF/ML_DomainAdaptation
# Out:
# Cloning into 'ML_DomainAdaptation'...
# remote: Enumerating objects: 110, done.
# remote: Counting objects: 100% (110/110), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 110 (delta 54), reused 70 (delta 25), pack-reused 0
# Receiving objects: 100% (110/110), 9.56 MiB | 18.43 MiB/s, done.
# Resolving deltas: 100% (54/54), done.

# %%
cd /content/ML_DomainAdaptation/Statistic_Criterion/
# Out:
# /content/ML_DomainAdaptation/Statistic_Criterion

# %% [markdown]
# ##### Let us begin by loading and preprocessing the source data: MNIST

# %%
(source_train_images, source_train_labels), (source_test_images, source_test_labels) = mnist.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step

# %%
source_train_images = source_train_images.reshape((60000, 28, 28, 1))

source_train_images = source_train_images.astype('float32') / 255

source_test_images = source_test_images.reshape((10000, 28, 28, 1))

source_test_images = source_test_images.astype('float32') / 255

source_train_labels = to_categorical(source_train_labels)
source_test_labels = to_categorical(source_test_labels)

# %% [markdown]
# ##### Let us now load and preprocess the target data: USPS

# %%
with h5py.File('usps_dataset.h5', 'r') as hf:
        train = hf.get('train')
        target_train_images_aux = train.get('data')[:]
        target_train_labels = train.get('target')[:]
        test = hf.get('test')
        target_test_images_aux = test.get('data')[:]
        target_test_labels = test.get('target')[:]

# %%
target_train_images = []
target_test_images = []

for i in range(7291):
    img = target_train_images_aux[i].reshape(16,16)
    img = cv2.resize(img, dsize=(28, 28), interpolation=cv2.INTER_CUBIC)
    target_train_images.append(img.flatten())
    
for i in range(2007):
    img = target_test_images_aux[i].reshape(16,16)
    img = cv2.resize(img, dsize=(28, 28), interpolation=cv2.INTER_CUBIC)
    target_test_images.append(img.flatten())

# %%
#convert list to numpy arrays
target_train_images = np.asarray(target_train_images)
target_test_images = np.asarray(target_test_images)

#train images
target_train_images = target_train_images.reshape((7291, 28, 28, 1))
target_train_images = target_train_images.astype('float32')
for i in range(7291):
    min_aux = np.min(target_train_images[i])
    max_aux = np.max(target_train_images[i]-min_aux)
    target_train_images[i] = (target_train_images[i]-min_aux)/max_aux

#test images
target_test_images = target_test_images.reshape((2007, 28, 28, 1))
target_test_images = target_test_images.astype('float32')
for i in range(2007):
    min_aux = np.min(target_test_images[i])
    max_aux = np.max(target_test_images[i]-min_aux)
    target_test_images[i] = (target_test_images[i]-min_aux)/max_aux

#labels
target_train_labels = to_categorical(target_train_labels)
target_test_labels = to_categorical(target_test_labels)

# %% [markdown]
# ## Loss
#
# Let us now code the $MMD^2(\boldsymbol{q}_s, \boldsymbol{\bar{q}}_t)$ loss where
# $$
# \boldsymbol{q}_s=W_1^Tx^s+b
# $$
# and
# $$
# \boldsymbol{\bar{q}}_t = W_1^Tx^t+b.
# $$

# %%
def compute_pairwise_distances(x, y):
    
    if not len(x.get_shape()) == len(y.get_shape()) == 2:
        raise ValueError('Both inputs should be matrices.')

    if x.get_shape().as_list()[1] != y.get_shape().as_list()[1]:
        raise ValueError('The number of features should be the same.')

    norm = lambda x: tf.reduce_sum(tf.square(x), 1)
    
    return tf.transpose(norm(tf.expand_dims(x, 2) - tf.transpose(y)))

# %%
def gaussian_kernel_matrix(x, y, sigmas = tf.constant([1e-2, 1e-1, 1, 5, 10])):
    
    beta = 1. / (2. * (tf.expand_dims(sigmas, 1)))
    dist = compute_pairwise_distances(x, y)
    s = tf.matmul(beta, tf.reshape(dist, (1, -1)))
    
    return tf.reshape(tf.reduce_sum(tf.exp(-s), 0), tf.shape(dist))

# %%
#loss
def mmd(y_true, y_pred):
    
    #revert the concatenation so as to recover the source and target outputs of the hidden layer
    y_pred_source = y_pred[:, :64]
    y_pred_target = y_pred[:, 64:]
    
    kernel = gaussian_kernel_matrix
    cost = tf.reduce_mean(kernel(y_pred_source, y_pred_source))
    cost += tf.reduce_mean(kernel(y_pred_target, y_pred_target))
    cost -= 2 * tf.reduce_mean(kernel(y_pred_source, y_pred_target))
    
    #cost has to be non-negative
    cost = tf.where(cost > 0, cost, 0)
    
    return cost

# %% [markdown]
# ## Model
#
# We create two models, the target and the source one, which consist of three convolutional layers interspersed with max poolings followed by two dense layers. After that, the adaptive layer (with 64 nodes) is placed. Finally, the output of the adaptive layer is fed into a final dense layer, which corresponds to the softmax. Until the adaptive layer, both models share weights.

# %%
#Function to get batches
def get_all_batches(data,labels,batch_size):
  idx = np.arange(0,data.shape[0])
  np.random.shuffle(idx)

  data_shuffle = data[idx,:]
  labels_shuffle = labels[idx]

  labels_shuffle = labels_shuffle[0:labels.shape[0] - labels.shape[0]%batch_size]
  data_shuffle = data_shuffle[0:labels.shape[0] - labels.shape[0]%batch_size,:]
  
  num_batches = data_shuffle.shape[0]/batch_size 
  batches_x =np.split(data_shuffle,num_batches)
  batches_y =np.split(labels_shuffle,num_batches)

  return batches_x,batches_y,num_batches

# %%
#Define larger model (CNN + fully connected)


def get_base_network(input_shape):

    inp = Input(shape = input_shape)
    #CNN layer +  relu
    x = Conv2D(32, kernel_size=(5, 5), activation='relu', input_shape=(28, 28, 1), padding='same')(inp)
    #Max pooling
    x = MaxPooling2D(pool_size=(2, 2))(x)

    #CNN layer + relu
    x = Conv2D(48, kernel_size=(5, 5), activation='relu', padding='same')(x)
    #Max pooling
    x = MaxPooling2D(pool_size=(2, 2))(x)

    #CNN layer + relu
    x = Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same')(x)
    #Max pooling
    x = MaxPooling2D(pool_size=(2, 2))(x)

    #Flatten

    x = Flatten()(x)

    #FC layers
    x = Dense(256, activation='relu')(x)
    x = Dense(84, activation='relu')(x)

    #Hidden layer: adaptive layer
    hidden = layers.Dense(64, activation='softplus', name='hidden')(x)

    return Model(inp, hidden)
  
input_shape = (28,28,1)

base_model= get_base_network(input_shape)

input_s = Input(shape=input_shape, name='source_input')
input_t = Input(shape=input_shape, name='target_input')

#Hidden layers

hidden_s = base_model(input_s)
hidden_t = base_model(input_t)

#concatenate outputs
aux_output = layers.concatenate([hidden_s, hidden_t], name='aux_output')

#Source Classifier
pred_s = layers.Dense(10, activation='softmax', name='source_output')(hidden_s)

#Target Classifier
pred_t = layers.Dense(10, activation='softmax', name='source_output')(hidden_t)


#Define target and source models

model_source = Model(input_s, pred_s)
model_target = Model([input_s,input_t],[aux_output,pred_t])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model_target.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# source_input (InputLayer)       (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# target_input (InputLayer)       (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 64)           241732      source_input[0][0]
#                                                                  target_input[0][0]
# __________________________________________________________________________________________________
# aux_output (Concatenate)        (None, 128)          0           model_1[1][0]
#                                                                  model_1[2][0]
# __________________________________________________________________________________________________
# source_output (Dense)           (None, 10)           650         model_1[2][0]
# ==================================================================================================
# Total params: 242,382
# Trainable params: 242,382
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_source.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(lr=0.001), metrics = ['accuracy'])
model_target.compile(loss=[mmd,'categorical_crossentropy'] ,loss_weights=[1.,1.], optimizer=keras.optimizers.Adam(lr=0.003), metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From <ipython-input-13-232c77bc61bd>:13: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
epochs = 30
batch_size=64
best_acc_source = 0
best_acc_target = 0
lr = 0.0025
loss_t=1

for iterations in range(epochs):
  source_batch_xs, source_batch_ys, num_batches_source = get_all_batches(source_train_images,source_train_labels,batch_size)
  target_batch_xs, target_batch_ys, num_batches_target = get_all_batches(target_train_images,target_train_labels,batch_size)

  num_batches = int(np.min([num_batches_source,num_batches_target]))

  for batch in range(num_batches):
    #Train source for each batch
    print('Epoch: ', iterations, ' Batch: ', batch)
    loss, acc = model_source.train_on_batch(source_batch_xs[batch], source_batch_ys[batch])
    print('Source loss: ', loss, ' Source acc: ', acc)
    #Save best source model
    if acc>best_acc_source:
      best_acc_source = acc
      best_source_model = model_source
      best_source_model.save_weights('source_model.hdf5') 

    if loss_t<0.02 and lr>0.001:
      model_target.compile(loss=mmd, optimizer=keras.optimizers.Adam(lr=0.0001), metrics = ['accuracy'])
      lr=0.001
    #Train target model
    loss_t,loss_t2,loss_t3, acc_t2, acc_t = model_target.train_on_batch({'source_input': source_batch_xs[batch], 'target_input': target_batch_xs[batch]},
                     {'aux_output': np.zeros(batch_size), 'source_output': target_batch_ys[batch]})
    
    print('Target loss: ', loss_t, ' Target acc: ', acc_t)

    #Save best target model
    if acc>best_acc_target:
      best_acc_target = acc
      best_target_model = model_target
      best_target_model.save_weights('target_model.hdf5')
# Out:
# Epoch:  0  Batch:  0
# Source loss:  0.026247427  Source acc:  1.0
# Target loss:  0.1789882  Target acc:  0.984375
# Epoch:  0  Batch:  1
# Source loss:  0.08795486  Source acc:  0.953125
# Target loss:  0.17313969  Target acc:  1.0
# Epoch:  0  Batch:  2
# Source loss:  0.10515571  Source acc:  0.96875
# Target loss:  0.15885523  Target acc:  1.0
# Epoch:  0  Batch:  3
# Source loss:  0.26775432  Source acc:  0.984375
# Target loss:  0.24863014  Target acc:  0.96875
# Epoch:  0  Batch:  4
# Source loss:  0.07071484  Source acc:  0.984375
# Target loss:  0.16682929  Target acc:  1.0
# Epoch:  0  Batch:  5
# Source loss:  0.049993284  Source acc:  0.96875
# Target loss:  0.15682764  Target acc:  1.0
# Epoch:  0  Batch:  6
# Source loss:  0.007499422  Source acc:  1.0
# Target loss:  0.16179422  Target acc:  1.0
# Epoch:  0  Batch:  7
# Source loss:  0.039161667  Source acc:  0.96875
# Target loss:  0.16068159  Target acc:  1.0
# Epoch:  0  Batch:  8
# Source loss:  0.28445214  Source acc:  0.9375
# Target loss:  0.1733719  Target acc:  1.0
# Epoch:  0  Batch:  9
# Source loss:  0.04864911  Source acc:  0.984375
# Target loss:  0.17749482  Target acc:  0.984375
# Epoch:  0  Batch:  10
# Source loss:  0.101077065  Source acc:  0.984375
# Target loss:  0.23689699  Target acc:  0.984375
# Epoch:  0  Batch:  11
# Source loss:  0.075276814  Source acc:  0.96875
# Target loss:  0.19368145  Target acc:  0.984375
# Epoch:  0  Batch:  12
# Source loss:  0.07885025  Source acc:  0.9375
# Target loss:  0.15779445  Target acc:  1.0
# Epoch:  0  Batch:  13
# Source loss:  0.06512434  Source acc:  0.984375
# Target loss:  0.16328387  Target acc:  1.0
# Epoch:  0  Batch:  14
# Source loss:  0.021504235  Source acc:  0.984375
# Target loss:  0.15744044  Target acc:  1.0
# Epoch:  0  Batch:  15
# Source loss:  0.14528185  Source acc:  0.96875
# Target loss:  0.16114402  Target acc:  1.0
# Epoch:  0  Batch:  16
# Source loss:  0.17012705  Source acc:  0.96875
# Target loss:  0.1577329  Target acc:  1.0
# Epoch:  0  Batch:  17
# Source loss:  0.14267373  Source acc:  0.9375
# Target loss:  0.15723246  Target acc:  1.0
# Epoch:  0  Batch:  18
# Source loss:  0.0320085  Source acc:  0.984375
# Target loss:  0.15896247  Target acc:  1.0
# Epoch:  0  Batch:  19
# Source loss:  0.05692576  Source acc:  0.96875
# Target loss:  0.1578263  Target acc:  1.0
# Epoch:  0  Batch:  20
# Source loss:  0.020954609  Source acc:  0.984375
# Target loss:  0.19498521  Target acc:  0.984375
# Epoch:  0  Batch:  21
# Source loss:  0.03401601  Source acc:  0.984375
# Target loss:  0.15927581  Target acc:  1.0
# Epoch:  0  Batch:  22
# Source loss:  0.18304785  Source acc:  0.9375
# Target loss:  0.15885575  Target acc:  1.0
# Epoch:  0  Batch:  23
# Source loss:  0.047090773  Source acc:  0.96875
# Target loss:  0.15953285  Target acc:  1.0
# Epoch:  0  Batch:  24
# Source loss:  0.033774696  Source acc:  0.984375
# Target loss:  0.15709972  Target acc:  1.0
# Epoch:  0  Batch:  25
# Source loss:  0.044471867  Source acc:  0.984375
# Target loss:  0.15682514  Target acc:  1.0
# Epoch:  0  Batch:  26
# Source loss:  0.00455918  Source acc:  1.0
# Target loss:  0.15794061  Target acc:  1.0
# Epoch:  0  Batch:  27
# Source loss:  0.013127626  Source acc:  1.0
# Target loss:  0.1564524  Target acc:  1.0
# Epoch:  0  Batch:  28
# Source loss:  0.13651095  Source acc:  0.96875
# Target loss:  0.16304404  Target acc:  1.0
# Epoch:  0  Batch:  29
# Source loss:  0.10389861  Source acc:  0.984375
# Target loss:  0.15817082  Target acc:  1.0
# Epoch:  0  Batch:  30
# Source loss:  0.12461444  Source acc:  0.96875
# Target loss:  0.15669255  Target acc:  1.0
# Epoch:  0  Batch:  31
# Source loss:  0.10475227  Source acc:  0.96875
# Target loss:  0.1574515  Target acc:  1.0
# Epoch:  0  Batch:  32
# Source loss:  0.20594496  Source acc:  0.96875
# Target loss:  0.15678656  Target acc:  1.0
# Epoch:  0  Batch:  33
# Source loss:  0.031757575  Source acc:  0.984375
# Target loss:  0.2783151  Target acc:  0.984375
# Epoch:  0  Batch:  34
# Source loss:  0.0070201503  Source acc:  1.0
# Target loss:  0.1643267  Target acc:  1.0
# Epoch:  0  Batch:  35
# Source loss:  0.045812603  Source acc:  0.984375
# Target loss:  0.15994881  Target acc:  1.0
# Epoch:  0  Batch:  36
# Source loss:  0.105674274  Source acc:  0.984375
# Target loss:  0.15635559  Target acc:  1.0
# Epoch:  0  Batch:  37
# Source loss:  0.21666478  Source acc:  0.96875
# Target loss:  0.27074686  Target acc:  0.96875
# Epoch:  0  Batch:  38
# Source loss:  0.22275612  Source acc:  0.9375
# Target loss:  0.15646297  Target acc:  1.0
# Epoch:  0  Batch:  39
# Source loss:  0.2829723  Source acc:  0.984375
# Target loss:  0.16105667  Target acc:  1.0
# Epoch:  0  Batch:  40
# Source loss:  0.16027969  Source acc:  0.96875
# Target loss:  0.2033644  Target acc:  0.984375
# Epoch:  0  Batch:  41
# Source loss:  0.1284773  Source acc:  0.9375
# Target loss:  0.28739804  Target acc:  0.984375
# Epoch:  0  Batch:  42
# Source loss:  0.07512112  Source acc:  0.953125
# Target loss:  0.23991323  Target acc:  0.96875
# Epoch:  0  Batch:  43
# Source loss:  0.026773268  Source acc:  0.984375
# Target loss:  0.15998736  Target acc:  1.0
# Epoch:  0  Batch:  44
# Source loss:  0.04950642  Source acc:  0.96875
# Target loss:  0.15882303  Target acc:  1.0
# Epoch:  0  Batch:  45
# Source loss:  0.16240516  Source acc:  0.953125
# Target loss:  0.1599376  Target acc:  1.0
# Epoch:  0  Batch:  46
# Source loss:  0.12482757  Source acc:  0.953125
# Target loss:  0.15832397  Target acc:  1.0
# Epoch:  0  Batch:  47
# Source loss:  0.0855313  Source acc:  0.953125
# Target loss:  0.4081493  Target acc:  0.984375
# Epoch:  0  Batch:  48
# Source loss:  0.13978915  Source acc:  0.9375
# Target loss:  0.24395424  Target acc:  0.984375
# Epoch:  0  Batch:  49
# Source loss:  0.29651988  Source acc:  0.9375
# Target loss:  0.17636764  Target acc:  0.984375
# Epoch:  0  Batch:  50
# Source loss:  0.062290538  Source acc:  0.984375
# Target loss:  0.15958741  Target acc:  1.0
# Epoch:  0  Batch:  51
# Source loss:  0.022001665  Source acc:  0.984375
# Target loss:  0.16384305  Target acc:  1.0
# Epoch:  0  Batch:  52
# Source loss:  0.117196746  Source acc:  0.96875
# Target loss:  0.15915579  Target acc:  1.0
# Epoch:  0  Batch:  53
# Source loss:  0.034172267  Source acc:  0.984375
# Target loss:  0.16581957  Target acc:  1.0
# Epoch:  0  Batch:  54
# Source loss:  0.005817777  Source acc:  1.0
# Target loss:  0.15728737  Target acc:  1.0
# Epoch:  0  Batch:  55
# Source loss:  0.05685731  Source acc:  0.984375
# Target loss:  0.15641458  Target acc:  1.0
# Epoch:  0  Batch:  56
# Source loss:  0.10592418  Source acc:  0.984375
# Target loss:  0.15756483  Target acc:  1.0
# Epoch:  0  Batch:  57
# Source loss:  0.023633512  Source acc:  0.984375
# Target loss:  0.17088719  Target acc:  0.984375
# Epoch:  0  Batch:  58
# Source loss:  0.042302396  Source acc:  0.984375
# Target loss:  0.15836547  Target acc:  1.0
# Epoch:  0  Batch:  59
# Source loss:  0.12854695  Source acc:  0.96875
# Target loss:  0.17102571  Target acc:  1.0
# Epoch:  0  Batch:  60
# Source loss:  0.15174334  Source acc:  0.96875
# Target loss:  0.22454101  Target acc:  0.984375
# Epoch:  0  Batch:  61
# Source loss:  0.10490972  Source acc:  0.96875
# Target loss:  0.15686885  Target acc:  1.0
# Epoch:  0  Batch:  62
# Source loss:  0.059441794  Source acc:  0.96875
# Target loss:  0.15868235  Target acc:  1.0
# Epoch:  0  Batch:  63
# Source loss:  0.055748  Source acc:  0.984375
# Target loss:  0.15681271  Target acc:  1.0
# Epoch:  0  Batch:  64
# Source loss:  0.11577288  Source acc:  0.984375
# Target loss:  0.20673881  Target acc:  0.984375
# Epoch:  0  Batch:  65
# Source loss:  0.08850864  Source acc:  0.984375
# Target loss:  0.15879218  Target acc:  1.0
# Epoch:  0  Batch:  66
# Source loss:  0.12894365  Source acc:  0.953125
# Target loss:  0.2304059  Target acc:  0.96875
# Epoch:  0  Batch:  67
# Source loss:  0.021565463  Source acc:  1.0
# Target loss:  0.19614786  Target acc:  0.984375
# Epoch:  0  Batch:  68
# Source loss:  0.19544727  Source acc:  0.9375
# Target loss:  0.19369361  Target acc:  0.984375
# Epoch:  0  Batch:  69
# Source loss:  0.10242154  Source acc:  0.953125
# Target loss:  0.15948986  Target acc:  1.0
# Epoch:  0  Batch:  70
# Source loss:  0.0726303  Source acc:  0.984375
# Target loss:  0.23151425  Target acc:  0.984375
# Epoch:  0  Batch:  71
# Source loss:  0.04971503  Source acc:  0.984375
# Target loss:  0.22839724  Target acc:  0.984375
# Epoch:  0  Batch:  72
# Source loss:  0.04442551  Source acc:  0.984375
# Target loss:  0.15896353  Target acc:  1.0
# Epoch:  0  Batch:  73
# Source loss:  0.17259975  Source acc:  0.96875
# Target loss:  0.15710433  Target acc:  1.0
# Epoch:  0  Batch:  74
# Source loss:  0.021730375  Source acc:  1.0
# Target loss:  0.16268277  Target acc:  1.0
# Epoch:  0  Batch:  75
# Source loss:  0.07378265  Source acc:  0.984375
# Target loss:  0.15777229  Target acc:  1.0
# Epoch:  0  Batch:  76
# Source loss:  0.13279596  Source acc:  0.953125
# Target loss:  0.15713906  Target acc:  1.0
# Epoch:  0  Batch:  77
# Source loss:  0.051388636  Source acc:  0.984375
# Target loss:  0.1587873  Target acc:  1.0
# Epoch:  0  Batch:  78
# Source loss:  0.17329912  Source acc:  0.984375
# Target loss:  0.16565688  Target acc:  1.0
# Epoch:  0  Batch:  79
# Source loss:  0.0808083  Source acc:  0.96875
# Target loss:  0.16110793  Target acc:  1.0
# Epoch:  0  Batch:  80
# Source loss:  0.23617555  Source acc:  0.890625
# Target loss:  0.15740642  Target acc:  1.0
# Epoch:  0  Batch:  81
# Source loss:  0.18034013  Source acc:  0.96875
# Target loss:  0.25930876  Target acc:  0.96875
# Epoch:  0  Batch:  82
# Source loss:  0.009956102  Source acc:  1.0
# Target loss:  0.15818827  Target acc:  1.0
# Epoch:  0  Batch:  83
# Source loss:  0.007151158  Source acc:  1.0
# Target loss:  0.16672803  Target acc:  1.0
# Epoch:  0  Batch:  84
# Source loss:  0.0718891  Source acc:  0.96875
# Target loss:  0.16643915  Target acc:  1.0
# Epoch:  0  Batch:  85
# Source loss:  0.07399404  Source acc:  0.984375
# Target loss:  0.19382238  Target acc:  0.984375
# Epoch:  0  Batch:  86
# Source loss:  0.059926778  Source acc:  0.984375
# Target loss:  0.16112742  Target acc:  1.0
# Epoch:  0  Batch:  87
# Source loss:  0.02428633  Source acc:  0.984375
# Target loss:  0.32032913  Target acc:  0.984375
# Epoch:  0  Batch:  88
# Source loss:  0.10625827  Source acc:  0.96875
# Target loss:  0.15769579  Target acc:  1.0
# Epoch:  0  Batch:  89
# Source loss:  0.037194658  Source acc:  1.0
# Target loss:  0.15964597  Target acc:  1.0
# Epoch:  0  Batch:  90
# Source loss:  0.05012077  Source acc:  1.0
# Target loss:  0.15862179  Target acc:  1.0
# Epoch:  0  Batch:  91
# Source loss:  0.028050356  Source acc:  0.984375
# Target loss:  0.2047361  Target acc:  0.984375
# Epoch:  0  Batch:  92
# Source loss:  0.13164553  Source acc:  0.96875
# Target loss:  0.16402261  Target acc:  1.0
# Epoch:  0  Batch:  93
# Source loss:  0.04186622  Source acc:  0.984375
# Target loss:  0.16257253  Target acc:  1.0
# Epoch:  0  Batch:  94
# Source loss:  0.1012626  Source acc:  0.984375
# Target loss:  0.15911919  Target acc:  1.0
# Epoch:  0  Batch:  95
# Source loss:  0.045009185  Source acc:  0.984375
# Target loss:  0.24243894  Target acc:  0.984375
# Epoch:  0  Batch:  96
# Source loss:  0.012785436  Source acc:  1.0
# Target loss:  0.18174624  Target acc:  0.984375
# Epoch:  0  Batch:  97
# Source loss:  0.20999646  Source acc:  0.96875
# Target loss:  0.18037754  Target acc:  0.984375
# Epoch:  0  Batch:  98
# Source loss:  0.16158016  Source acc:  0.96875
# Target loss:  0.15719177  Target acc:  1.0
# Epoch:  0  Batch:  99
# Source loss:  0.005151308  Source acc:  1.0
# Target loss:  0.15857469  Target acc:  1.0
# Epoch:  0  Batch:  100
# Source loss:  0.04266792  Source acc:  0.984375
# Target loss:  0.16202334  Target acc:  1.0
# Epoch:  0  Batch:  101
# Source loss:  0.016739933  Source acc:  0.984375
# Target loss:  0.16019557  Target acc:  1.0
# Epoch:  0  Batch:  102
# Source loss:  0.0729499  Source acc:  0.96875
# Target loss:  0.15887645  Target acc:  1.0
# Epoch:  0  Batch:  103
# Source loss:  0.011088703  Source acc:  1.0
# Target loss:  0.23654896  Target acc:  0.984375
# Epoch:  0  Batch:  104
# Source loss:  0.17598388  Source acc:  0.96875
# Target loss:  0.15747301  Target acc:  1.0
# Epoch:  0  Batch:  105
# Source loss:  0.24318151  Source acc:  0.953125
# Target loss:  0.15881099  Target acc:  1.0
# Epoch:  0  Batch:  106
# Source loss:  0.128589  Source acc:  0.953125
# Target loss:  0.16006665  Target acc:  1.0
# Epoch:  0  Batch:  107
# Source loss:  0.107442796  Source acc:  0.96875
# Target loss:  0.15897699  Target acc:  1.0
# Epoch:  0  Batch:  108
# Source loss:  0.08243267  Source acc:  0.984375
# Target loss:  0.15810141  Target acc:  1.0
# Epoch:  0  Batch:  109
# Source loss:  0.015270159  Source acc:  1.0
# Target loss:  0.20530249  Target acc:  0.984375
# Epoch:  0  Batch:  110
# Source loss:  0.09285065  Source acc:  0.984375
# Target loss:  0.20647132  Target acc:  0.984375
# Epoch:  0  Batch:  111
# Source loss:  0.1824732  Source acc:  0.96875
# Target loss:  0.15807703  Target acc:  1.0
# Epoch:  0  Batch:  112
# Source loss:  0.074293554  Source acc:  0.96875
# Target loss:  0.19889453  Target acc:  0.984375
# Epoch:  1  Batch:  0
# Source loss:  0.12409497  Source acc:  0.96875
# Target loss:  0.35824254  Target acc:  0.96875
# Epoch:  1  Batch:  1
# Source loss:  0.18875755  Source acc:  0.96875
# Target loss:  0.1602135  Target acc:  1.0
# Epoch:  1  Batch:  2
# Source loss:  0.037943855  Source acc:  0.984375
# Target loss:  0.15733725  Target acc:  1.0
# Epoch:  1  Batch:  3
# Source loss:  0.042648464  Source acc:  0.984375
# Target loss:  0.15911694  Target acc:  1.0
# Epoch:  1  Batch:  4
# Source loss:  0.19678429  Source acc:  0.96875
# Target loss:  0.17644952  Target acc:  0.984375
# Epoch:  1  Batch:  5
# Source loss:  0.07233878  Source acc:  0.96875
# Target loss:  0.19269074  Target acc:  0.984375
# Epoch:  1  Batch:  6
# Source loss:  0.022893384  Source acc:  1.0
# Target loss:  0.15823294  Target acc:  1.0
# Epoch:  1  Batch:  7
# Source loss:  0.023477213  Source acc:  1.0
# Target loss:  0.15886879  Target acc:  1.0
# Epoch:  1  Batch:  8
# Source loss:  0.054276966  Source acc:  0.984375
# Target loss:  0.16190307  Target acc:  1.0
# Epoch:  1  Batch:  9
# Source loss:  0.056441307  Source acc:  0.984375
# Target loss:  0.15696763  Target acc:  1.0
# Epoch:  1  Batch:  10
# Source loss:  0.17513528  Source acc:  0.953125
# Target loss:  0.15679033  Target acc:  1.0
# Epoch:  1  Batch:  11
# Source loss:  0.04754533  Source acc:  0.96875
# Target loss:  0.15789405  Target acc:  1.0
# Epoch:  1  Batch:  12
# Source loss:  0.15524861  Source acc:  0.96875
# Target loss:  0.23519465  Target acc:  0.984375
# Epoch:  1  Batch:  13
# Source loss:  0.19597246  Source acc:  0.953125
# Target loss:  0.15726744  Target acc:  1.0
# Epoch:  1  Batch:  14
# Source loss:  0.0392076  Source acc:  1.0
# Target loss:  0.15681346  Target acc:  1.0
# Epoch:  1  Batch:  15
# Source loss:  0.10839714  Source acc:  0.984375
# Target loss:  0.16312115  Target acc:  1.0
# Epoch:  1  Batch:  16
# Source loss:  0.1785567  Source acc:  0.96875
# Target loss:  0.15728371  Target acc:  1.0
# Epoch:  1  Batch:  17
# Source loss:  0.01632002  Source acc:  1.0
# Target loss:  0.157188  Target acc:  1.0
# Epoch:  1  Batch:  18
# Source loss:  0.19442919  Source acc:  0.96875
# Target loss:  0.15745564  Target acc:  1.0
# Epoch:  1  Batch:  19
# Source loss:  0.07076079  Source acc:  0.96875
# Target loss:  0.19643375  Target acc:  0.984375
# Epoch:  1  Batch:  20
# Source loss:  0.0019009579  Source acc:  1.0
# Target loss:  0.15612197  Target acc:  1.0
# Epoch:  1  Batch:  21
# Source loss:  0.04907123  Source acc:  0.984375
# Target loss:  0.15902008  Target acc:  1.0
# Epoch:  1  Batch:  22
# Source loss:  0.059508752  Source acc:  0.96875
# Target loss:  0.15665954  Target acc:  1.0
# Epoch:  1  Batch:  23
# Source loss:  0.041410737  Source acc:  0.984375
# Target loss:  0.1556887  Target acc:  1.0
# Epoch:  1  Batch:  24
# Source loss:  0.05495829  Source acc:  0.96875
# Target loss:  0.15685944  Target acc:  1.0
# Epoch:  1  Batch:  25
# Source loss:  0.0012863348  Source acc:  1.0
# Target loss:  0.15721919  Target acc:  1.0
# Epoch:  1  Batch:  26
# Source loss:  0.07375466  Source acc:  0.984375
# Target loss:  0.15660316  Target acc:  1.0
# Epoch:  1  Batch:  27
# Source loss:  0.007950096  Source acc:  1.0
# Target loss:  0.15989627  Target acc:  1.0
# Epoch:  1  Batch:  28
# Source loss:  0.043886364  Source acc:  0.984375
# Target loss:  0.15740007  Target acc:  1.0
# Epoch:  1  Batch:  29
# Source loss:  0.01043306  Source acc:  1.0
# Target loss:  0.15742688  Target acc:  1.0
# Epoch:  1  Batch:  30
# Source loss:  0.031052722  Source acc:  0.984375
# Target loss:  0.15655473  Target acc:  1.0
# Epoch:  1  Batch:  31
# Source loss:  0.06771377  Source acc:  0.984375
# Target loss:  0.16545026  Target acc:  1.0
# Epoch:  1  Batch:  32
# Source loss:  0.0745238  Source acc:  0.96875
# Target loss:  0.194365  Target acc:  0.984375
# Epoch:  1  Batch:  33
# Source loss:  0.18541242  Source acc:  0.953125
# Target loss:  0.1593427  Target acc:  1.0
# Epoch:  1  Batch:  34
# Source loss:  0.067006126  Source acc:  0.984375
# Target loss:  0.1587645  Target acc:  1.0
# Epoch:  1  Batch:  35
# Source loss:  0.025917083  Source acc:  0.984375
# Target loss:  0.16634448  Target acc:  1.0
# Epoch:  1  Batch:  36
# Source loss:  0.039649304  Source acc:  0.984375
# Target loss:  0.15825713  Target acc:  1.0
# Epoch:  1  Batch:  37
# Source loss:  0.015198042  Source acc:  1.0
# Target loss:  0.2473104  Target acc:  0.96875
# Epoch:  1  Batch:  38
# Source loss:  0.102631666  Source acc:  0.984375
# Target loss:  0.1563081  Target acc:  1.0
# Epoch:  1  Batch:  39
# Source loss:  0.028452799  Source acc:  0.984375
# Target loss:  0.15691042  Target acc:  1.0
# Epoch:  1  Batch:  40
# Source loss:  0.20160222  Source acc:  0.984375
# Target loss:  0.15769711  Target acc:  1.0
# Epoch:  1  Batch:  41
# Source loss:  0.26808688  Source acc:  0.953125
# Target loss:  0.15854807  Target acc:  1.0
# Epoch:  1  Batch:  42
# Source loss:  0.22644597  Source acc:  0.96875
# Target loss:  0.15886688  Target acc:  1.0
# Epoch:  1  Batch:  43
# Source loss:  0.12915789  Source acc:  0.953125
# Target loss:  0.15678778  Target acc:  1.0
# Epoch:  1  Batch:  44
# Source loss:  0.425225  Source acc:  0.921875
# Target loss:  0.17912327  Target acc:  0.984375
# Epoch:  1  Batch:  45
# Source loss:  0.099953786  Source acc:  0.953125
# Target loss:  0.30399764  Target acc:  0.984375
# Epoch:  1  Batch:  46
# Source loss:  0.027815312  Source acc:  1.0
# Target loss:  0.22443627  Target acc:  0.984375
# Epoch:  1  Batch:  47
# Source loss:  0.005836907  Source acc:  1.0
# Target loss:  0.1577681  Target acc:  1.0
# Epoch:  1  Batch:  48
# Source loss:  0.01770101  Source acc:  1.0
# Target loss:  0.1574509  Target acc:  1.0
# Epoch:  1  Batch:  49
# Source loss:  0.024532918  Source acc:  0.984375
# Target loss:  0.15726134  Target acc:  1.0
# Epoch:  1  Batch:  50
# Source loss:  0.058279105  Source acc:  0.984375
# Target loss:  0.17576951  Target acc:  0.984375
# Epoch:  1  Batch:  51
# Source loss:  0.071922936  Source acc:  0.96875
# Target loss:  0.16370231  Target acc:  1.0
# Epoch:  1  Batch:  52
# Source loss:  0.03146324  Source acc:  1.0
# Target loss:  0.16476956  Target acc:  1.0
# Epoch:  1  Batch:  53
# Source loss:  0.10096926  Source acc:  0.96875
# Target loss:  0.15760121  Target acc:  1.0
# Epoch:  1  Batch:  54
# Source loss:  0.02647081  Source acc:  0.984375
# Target loss:  0.19416778  Target acc:  0.984375
# Epoch:  1  Batch:  55
# Source loss:  0.11989118  Source acc:  0.96875
# Target loss:  0.16928321  Target acc:  1.0
# Epoch:  1  Batch:  56
# Source loss:  0.06790901  Source acc:  0.96875
# Target loss:  0.15737702  Target acc:  1.0
# Epoch:  1  Batch:  57
# Source loss:  0.05135195  Source acc:  0.984375
# Target loss:  0.15712127  Target acc:  1.0
# Epoch:  1  Batch:  58
# Source loss:  0.101098165  Source acc:  0.984375
# Target loss:  0.16597807  Target acc:  1.0
# Epoch:  1  Batch:  59
# Source loss:  0.05873512  Source acc:  0.984375
# Target loss:  0.16327941  Target acc:  1.0
# Epoch:  1  Batch:  60
# Source loss:  0.11111079  Source acc:  0.96875
# Target loss:  0.15776531  Target acc:  1.0
# Epoch:  1  Batch:  61
# Source loss:  0.1281858  Source acc:  0.96875
# Target loss:  0.15924546  Target acc:  1.0
# Epoch:  1  Batch:  62
# Source loss:  0.022612035  Source acc:  0.984375
# Target loss:  0.22141439  Target acc:  0.96875
# Epoch:  1  Batch:  63
# Source loss:  0.09264203  Source acc:  0.96875
# Target loss:  0.16072847  Target acc:  1.0
# Epoch:  1  Batch:  64
# Source loss:  0.07560137  Source acc:  0.984375
# Target loss:  0.15729906  Target acc:  1.0
# Epoch:  1  Batch:  65
# Source loss:  0.045731295  Source acc:  0.984375
# Target loss:  0.15563561  Target acc:  1.0
# Epoch:  1  Batch:  66
# Source loss:  0.1700668  Source acc:  0.953125
# Target loss:  0.15746813  Target acc:  1.0
# Epoch:  1  Batch:  67
# Source loss:  0.06141719  Source acc:  0.96875
# Target loss:  0.15751103  Target acc:  1.0
# Epoch:  1  Batch:  68
# Source loss:  0.30525756  Source acc:  0.953125
# Target loss:  0.1570438  Target acc:  1.0
# Epoch:  1  Batch:  69
# Source loss:  0.18647163  Source acc:  0.953125
# Target loss:  0.15833703  Target acc:  1.0
# Epoch:  1  Batch:  70
# Source loss:  0.1423403  Source acc:  0.984375
# Target loss:  0.15871681  Target acc:  1.0
# Epoch:  1  Batch:  71
# Source loss:  0.03397893  Source acc:  1.0
# Target loss:  0.15779372  Target acc:  1.0
# Epoch:  1  Batch:  72
# Source loss:  0.033709884  Source acc:  0.984375
# Target loss:  0.28838378  Target acc:  0.96875
# Epoch:  1  Batch:  73
# Source loss:  0.012837809  Source acc:  1.0
# Target loss:  0.15682171  Target acc:  1.0
# Epoch:  1  Batch:  74
# Source loss:  0.10174015  Source acc:  0.96875
# Target loss:  0.15823212  Target acc:  1.0
# Epoch:  1  Batch:  75
# Source loss:  0.035797536  Source acc:  0.984375
# Target loss:  0.15824774  Target acc:  1.0
# Epoch:  1  Batch:  76
# Source loss:  0.021229507  Source acc:  0.984375
# Target loss:  0.16472363  Target acc:  1.0
# Epoch:  1  Batch:  77
# Source loss:  0.053806387  Source acc:  0.984375
# Target loss:  0.15783785  Target acc:  1.0
# Epoch:  1  Batch:  78
# Source loss:  0.117468454  Source acc:  0.984375
# Target loss:  0.15756513  Target acc:  1.0
# Epoch:  1  Batch:  79
# Source loss:  0.10024155  Source acc:  0.984375
# Target loss:  0.15926895  Target acc:  1.0
# Epoch:  1  Batch:  80
# Source loss:  0.089403994  Source acc:  0.953125
# Target loss:  0.15642238  Target acc:  1.0
# Epoch:  1  Batch:  81
# Source loss:  0.095034376  Source acc:  0.96875
# Target loss:  0.15769954  Target acc:  1.0
# Epoch:  1  Batch:  82
# Source loss:  0.022671018  Source acc:  1.0
# Target loss:  0.34714276  Target acc:  0.984375
# Epoch:  1  Batch:  83
# Source loss:  0.04376041  Source acc:  0.984375
# Target loss:  0.15822701  Target acc:  1.0
# Epoch:  1  Batch:  84
# Source loss:  0.08344529  Source acc:  0.984375
# Target loss:  0.15678176  Target acc:  1.0
# Epoch:  1  Batch:  85
# Source loss:  0.1728175  Source acc:  0.984375
# Target loss:  0.18215305  Target acc:  0.984375
# Epoch:  1  Batch:  86
# Source loss:  0.072481886  Source acc:  0.984375
# Target loss:  0.16185305  Target acc:  1.0
# Epoch:  1  Batch:  87
# Source loss:  0.009051006  Source acc:  1.0
# Target loss:  0.16624814  Target acc:  1.0
# Epoch:  1  Batch:  88
# Source loss:  0.049233027  Source acc:  0.984375
# Target loss:  0.1580327  Target acc:  1.0
# Epoch:  1  Batch:  89
# Source loss:  0.016193971  Source acc:  1.0
# Target loss:  0.155647  Target acc:  1.0
# Epoch:  1  Batch:  90
# Source loss:  0.028787322  Source acc:  1.0
# Target loss:  0.15826967  Target acc:  1.0
# Epoch:  1  Batch:  91
# Source loss:  0.09035277  Source acc:  0.96875
# Target loss:  0.16084263  Target acc:  1.0
# Epoch:  1  Batch:  92
# Source loss:  0.024098922  Source acc:  0.984375
# Target loss:  0.15702862  Target acc:  1.0
# Epoch:  1  Batch:  93
# Source loss:  0.010266634  Source acc:  1.0
# Target loss:  0.15854481  Target acc:  1.0
# Epoch:  1  Batch:  94
# Source loss:  0.027614858  Source acc:  1.0
# Target loss:  0.1577761  Target acc:  1.0
# Epoch:  1  Batch:  95
# Source loss:  0.054216772  Source acc:  0.96875
# Target loss:  0.15683717  Target acc:  1.0
# Epoch:  1  Batch:  96
# Source loss:  0.0015239341  Source acc:  1.0
# Target loss:  0.1623453  Target acc:  1.0
# Epoch:  1  Batch:  97
# Source loss:  0.006993804  Source acc:  1.0
# Target loss:  0.1569668  Target acc:  1.0
# Epoch:  1  Batch:  98
# Source loss:  0.06667957  Source acc:  0.96875
# Target loss:  0.15888563  Target acc:  1.0
# Epoch:  1  Batch:  99
# Source loss:  0.022131223  Source acc:  0.984375
# Target loss:  0.15648742  Target acc:  1.0
# Epoch:  1  Batch:  100
# Source loss:  0.029009918  Source acc:  1.0
# Target loss:  0.1598553  Target acc:  1.0
# Epoch:  1  Batch:  101
# Source loss:  0.0021430897  Source acc:  1.0
# Target loss:  0.1573753  Target acc:  1.0
# Epoch:  1  Batch:  102
# Source loss:  0.07860989  Source acc:  0.984375
# Target loss:  0.16614836  Target acc:  1.0
# Epoch:  1  Batch:  103
# Source loss:  0.024587749  Source acc:  1.0
# Target loss:  0.15823907  Target acc:  1.0
# Epoch:  1  Batch:  104
# Source loss:  0.0656389  Source acc:  0.953125
# Target loss:  0.15603426  Target acc:  1.0
# Epoch:  1  Batch:  105
# Source loss:  0.01630952  Source acc:  1.0
# Target loss:  0.2586573  Target acc:  0.984375
# Epoch:  1  Batch:  106
# Source loss:  0.088980824  Source acc:  0.984375
# Target loss:  0.16865899  Target acc:  1.0
# Epoch:  1  Batch:  107
# Source loss:  0.06429194  Source acc:  0.984375
# Target loss:  0.16237478  Target acc:  1.0
# Epoch:  1  Batch:  108
# Source loss:  0.056600124  Source acc:  0.984375
# Target loss:  0.1743243  Target acc:  0.984375
# Epoch:  1  Batch:  109
# Source loss:  0.063414186  Source acc:  0.984375
# Target loss:  0.15786077  Target acc:  1.0
# Epoch:  1  Batch:  110
# Source loss:  0.019057859  Source acc:  0.984375
# Target loss:  0.1569982  Target acc:  1.0
# Epoch:  1  Batch:  111
# Source loss:  0.0077895136  Source acc:  1.0
# Target loss:  0.15679938  Target acc:  1.0
# Epoch:  1  Batch:  112
# Source loss:  0.115073636  Source acc:  0.984375
# Target loss:  0.15757173  Target acc:  1.0
# Epoch:  2  Batch:  0
# Source loss:  0.014091801  Source acc:  1.0
# Target loss:  0.15740213  Target acc:  1.0
# Epoch:  2  Batch:  1
# Source loss:  0.027361307  Source acc:  1.0
# Target loss:  0.15885213  Target acc:  1.0
# Epoch:  2  Batch:  2
# Source loss:  0.0841869  Source acc:  0.984375
# Target loss:  0.15808718  Target acc:  1.0
# Epoch:  2  Batch:  3
# Source loss:  0.003010531  Source acc:  1.0
# Target loss:  0.15690412  Target acc:  1.0
# Epoch:  2  Batch:  4
# Source loss:  0.016268097  Source acc:  1.0
# Target loss:  0.1574974  Target acc:  1.0
# Epoch:  2  Batch:  5
# Source loss:  0.05224651  Source acc:  0.984375
# Target loss:  0.15690826  Target acc:  1.0
# Epoch:  2  Batch:  6
# Source loss:  0.018629896  Source acc:  0.984375
# Target loss:  0.15758921  Target acc:  1.0
# Epoch:  2  Batch:  7
# Source loss:  0.016786031  Source acc:  0.984375
# Target loss:  0.16003525  Target acc:  1.0
# Epoch:  2  Batch:  8
# Source loss:  0.014025106  Source acc:  0.984375
# Target loss:  0.15834749  Target acc:  1.0
# Epoch:  2  Batch:  9
# Source loss:  0.06599829  Source acc:  0.984375
# Target loss:  0.15707244  Target acc:  1.0
# Epoch:  2  Batch:  10
# Source loss:  0.012740002  Source acc:  1.0
# Target loss:  0.15674956  Target acc:  1.0
# Epoch:  2  Batch:  11
# Source loss:  0.024289506  Source acc:  1.0
# Target loss:  0.16955572  Target acc:  0.984375
# Epoch:  2  Batch:  12
# Source loss:  0.011733415  Source acc:  0.984375
# Target loss:  0.15844208  Target acc:  1.0
# Epoch:  2  Batch:  13
# Source loss:  0.06133286  Source acc:  0.984375
# Target loss:  0.1571266  Target acc:  1.0
# Epoch:  2  Batch:  14
# Source loss:  0.08027438  Source acc:  0.984375
# Target loss:  0.15659004  Target acc:  1.0
# Epoch:  2  Batch:  15
# Source loss:  0.0016062101  Source acc:  1.0
# Target loss:  0.15781087  Target acc:  1.0
# Epoch:  2  Batch:  16
# Source loss:  0.00082676776  Source acc:  1.0
# Target loss:  0.15695515  Target acc:  1.0
# Epoch:  2  Batch:  17
# Source loss:  0.054296207  Source acc:  0.984375
# Target loss:  0.15715091  Target acc:  1.0
# Epoch:  2  Batch:  18
# Source loss:  0.026993897  Source acc:  1.0
# Target loss:  0.15651083  Target acc:  1.0
# Epoch:  2  Batch:  19
# Source loss:  0.062098134  Source acc:  0.984375
# Target loss:  0.15658092  Target acc:  1.0
# Epoch:  2  Batch:  20
# Source loss:  0.016225632  Source acc:  1.0
# Target loss:  0.15720595  Target acc:  1.0
# Epoch:  2  Batch:  21
# Source loss:  0.14416745  Source acc:  0.953125
# Target loss:  0.15734774  Target acc:  1.0
# Epoch:  2  Batch:  22
# Source loss:  0.027025845  Source acc:  1.0
# Target loss:  0.15747508  Target acc:  1.0
# Epoch:  2  Batch:  23
# Source loss:  0.009443653  Source acc:  1.0
# Target loss:  0.15656893  Target acc:  1.0
# Epoch:  2  Batch:  24
# Source loss:  0.08928429  Source acc:  0.96875
# Target loss:  0.15691029  Target acc:  1.0
# Epoch:  2  Batch:  25
# Source loss:  0.005632096  Source acc:  1.0
# Target loss:  0.15625866  Target acc:  1.0
# Epoch:  2  Batch:  26
# Source loss:  0.015185212  Source acc:  1.0
# Target loss:  0.15840147  Target acc:  1.0
# Epoch:  2  Batch:  27
# Source loss:  0.0052541895  Source acc:  1.0
# Target loss:  0.15695615  Target acc:  1.0
# Epoch:  2  Batch:  28
# Source loss:  0.14136836  Source acc:  0.96875
# Target loss:  0.15757829  Target acc:  1.0
# Epoch:  2  Batch:  29
# Source loss:  0.060401656  Source acc:  0.96875
# Target loss:  0.15719983  Target acc:  1.0
# Epoch:  2  Batch:  30
# Source loss:  0.017040083  Source acc:  0.984375
# Target loss:  0.15734473  Target acc:  1.0
# Epoch:  2  Batch:  31
# Source loss:  0.17500482  Source acc:  0.96875
# Target loss:  0.15659918  Target acc:  1.0
# Epoch:  2  Batch:  32
# Source loss:  0.0574462  Source acc:  0.984375
# Target loss:  0.15669227  Target acc:  1.0
# Epoch:  2  Batch:  33
# Source loss:  0.0068144756  Source acc:  1.0
# Target loss:  0.1570468  Target acc:  1.0
# Epoch:  2  Batch:  34
# Source loss:  0.00089911197  Source acc:  1.0
# Target loss:  0.15589646  Target acc:  1.0
# Epoch:  2  Batch:  35
# Source loss:  0.15063354  Source acc:  0.953125
# Target loss:  0.15730856  Target acc:  1.0
# Epoch:  2  Batch:  36
# Source loss:  0.010434729  Source acc:  1.0
# Target loss:  0.15742944  Target acc:  1.0
# Epoch:  2  Batch:  37
# Source loss:  0.009287884  Source acc:  1.0
# Target loss:  0.15650459  Target acc:  1.0
# Epoch:  2  Batch:  38
# Source loss:  0.058070347  Source acc:  0.984375
# Target loss:  0.15652885  Target acc:  1.0
# Epoch:  2  Batch:  39
# Source loss:  0.0014231065  Source acc:  1.0
# Target loss:  0.15718378  Target acc:  1.0
# Epoch:  2  Batch:  40
# Source loss:  0.1681882  Source acc:  0.984375
# Target loss:  0.15753894  Target acc:  1.0
# Epoch:  2  Batch:  41
# Source loss:  0.018744543  Source acc:  1.0
# Target loss:  0.15700398  Target acc:  1.0
# Epoch:  2  Batch:  42
# Source loss:  0.07431443  Source acc:  0.96875
# Target loss:  0.15750739  Target acc:  1.0
# Epoch:  2  Batch:  43
# Source loss:  0.014644861  Source acc:  1.0
# Target loss:  0.15704744  Target acc:  1.0
# Epoch:  2  Batch:  44
# Source loss:  0.0016318411  Source acc:  1.0
# Target loss:  0.1565941  Target acc:  1.0
# Epoch:  2  Batch:  45
# Source loss:  0.037893746  Source acc:  0.984375
# Target loss:  0.15662025  Target acc:  1.0
# Epoch:  2  Batch:  46
# Source loss:  0.0005511766  Source acc:  1.0
# Target loss:  0.15629832  Target acc:  1.0
# Epoch:  2  Batch:  47
# Source loss:  0.009450356  Source acc:  1.0
# Target loss:  0.15693182  Target acc:  1.0
# Epoch:  2  Batch:  48
# Source loss:  0.0036630451  Source acc:  1.0
# Target loss:  0.15649202  Target acc:  1.0
# Epoch:  2  Batch:  49
# Source loss:  0.08265848  Source acc:  0.984375
# Target loss:  0.15742196  Target acc:  1.0
# Epoch:  2  Batch:  50
# Source loss:  0.10927171  Source acc:  0.96875
# Target loss:  0.1561817  Target acc:  1.0
# Epoch:  2  Batch:  51
# Source loss:  0.08378415  Source acc:  0.984375
# Target loss:  0.15719372  Target acc:  1.0
# Epoch:  2  Batch:  52
# Source loss:  0.006038909  Source acc:  1.0
# Target loss:  0.1566365  Target acc:  1.0
# Epoch:  2  Batch:  53
# Source loss:  0.0016543514  Source acc:  1.0
# Target loss:  0.15781626  Target acc:  1.0
# Epoch:  2  Batch:  54
# Source loss:  0.14990894  Source acc:  0.96875
# Target loss:  0.15744014  Target acc:  1.0
# Epoch:  2  Batch:  55
# Source loss:  0.0061447076  Source acc:  1.0
# Target loss:  0.15739316  Target acc:  1.0
# Epoch:  2  Batch:  56
# Source loss:  0.08927356  Source acc:  0.984375
# Target loss:  0.15623458  Target acc:  1.0
# Epoch:  2  Batch:  57
# Source loss:  0.012022506  Source acc:  1.0
# Target loss:  0.15639904  Target acc:  1.0
# Epoch:  2  Batch:  58
# Source loss:  0.029271666  Source acc:  0.984375
# Target loss:  0.15669489  Target acc:  1.0
# Epoch:  2  Batch:  59
# Source loss:  0.06395951  Source acc:  0.96875
# Target loss:  0.15630308  Target acc:  1.0
# Epoch:  2  Batch:  60
# Source loss:  0.0025774247  Source acc:  1.0
# Target loss:  0.15604094  Target acc:  1.0
# Epoch:  2  Batch:  61
# Source loss:  0.06903502  Source acc:  0.96875
# Target loss:  0.15667702  Target acc:  1.0
# Epoch:  2  Batch:  62
# Source loss:  0.121332645  Source acc:  0.96875
# Target loss:  0.15673079  Target acc:  1.0
# Epoch:  2  Batch:  63
# Source loss:  0.021246456  Source acc:  0.984375
# Target loss:  0.16273369  Target acc:  1.0
# Epoch:  2  Batch:  64
# Source loss:  0.010197097  Source acc:  1.0
# Target loss:  0.15656255  Target acc:  1.0
# Epoch:  2  Batch:  65
# Source loss:  0.110654294  Source acc:  0.984375
# Target loss:  0.15798421  Target acc:  1.0
# Epoch:  2  Batch:  66
# Source loss:  0.006348717  Source acc:  1.0
# Target loss:  0.15696265  Target acc:  1.0
# Epoch:  2  Batch:  67
# Source loss:  0.0046900953  Source acc:  1.0
# Target loss:  0.15700309  Target acc:  1.0
# Epoch:  2  Batch:  68
# Source loss:  0.006880058  Source acc:  1.0
# Target loss:  0.15689942  Target acc:  1.0
# Epoch:  2  Batch:  69
# Source loss:  0.045061238  Source acc:  0.984375
# Target loss:  0.15810597  Target acc:  1.0
# Epoch:  2  Batch:  70
# Source loss:  0.030534763  Source acc:  0.984375
# Target loss:  0.157586  Target acc:  1.0
# Epoch:  2  Batch:  71
# Source loss:  0.0019196294  Source acc:  1.0
# Target loss:  0.15659866  Target acc:  1.0
# Epoch:  2  Batch:  72
# Source loss:  0.07720699  Source acc:  0.984375
# Target loss:  0.15673116  Target acc:  1.0
# Epoch:  2  Batch:  73
# Source loss:  0.11035366  Source acc:  0.984375
# Target loss:  0.18654475  Target acc:  0.984375
# Epoch:  2  Batch:  74
# Source loss:  0.003108372  Source acc:  1.0
# Target loss:  0.15665807  Target acc:  1.0
# Epoch:  2  Batch:  75
# Source loss:  0.001655749  Source acc:  1.0
# Target loss:  0.15601717  Target acc:  1.0
# Epoch:  2  Batch:  76
# Source loss:  0.010285089  Source acc:  1.0
# Target loss:  0.15555704  Target acc:  1.0
# Epoch:  2  Batch:  77
# Source loss:  0.19537482  Source acc:  0.9375
# Target loss:  0.15670143  Target acc:  1.0
# Epoch:  2  Batch:  78
# Source loss:  0.0039047867  Source acc:  1.0
# Target loss:  0.15680546  Target acc:  1.0
# Epoch:  2  Batch:  79
# Source loss:  0.0021647713  Source acc:  1.0
# Target loss:  0.15640312  Target acc:  1.0
# Epoch:  2  Batch:  80
# Source loss:  0.020693935  Source acc:  0.984375
# Target loss:  0.34570974  Target acc:  0.96875
# Epoch:  2  Batch:  81
# Source loss:  0.049353  Source acc:  0.984375
# Target loss:  0.15715963  Target acc:  1.0
# Epoch:  2  Batch:  82
# Source loss:  0.04177391  Source acc:  0.96875
# Target loss:  0.15709652  Target acc:  1.0
# Epoch:  2  Batch:  83
# Source loss:  0.00635559  Source acc:  1.0
# Target loss:  0.15846442  Target acc:  1.0
# Epoch:  2  Batch:  84
# Source loss:  0.06904119  Source acc:  0.984375
# Target loss:  0.15770248  Target acc:  1.0
# Epoch:  2  Batch:  85
# Source loss:  0.090850145  Source acc:  0.96875
# Target loss:  0.18052064  Target acc:  0.984375
# Epoch:  2  Batch:  86
# Source loss:  0.081780635  Source acc:  0.984375
# Target loss:  0.15769638  Target acc:  1.0
# Epoch:  2  Batch:  87
# Source loss:  0.019137956  Source acc:  0.984375
# Target loss:  0.15731698  Target acc:  1.0
# Epoch:  2  Batch:  88
# Source loss:  0.0009732951  Source acc:  1.0
# Target loss:  0.15769055  Target acc:  1.0
# Epoch:  2  Batch:  89
# Source loss:  0.07264936  Source acc:  0.984375
# Target loss:  0.15831992  Target acc:  1.0
# Epoch:  2  Batch:  90
# Source loss:  0.0045747375  Source acc:  1.0
# Target loss:  0.15770577  Target acc:  1.0
# Epoch:  2  Batch:  91
# Source loss:  0.02471856  Source acc:  0.984375
# Target loss:  0.19100589  Target acc:  0.984375
# Epoch:  2  Batch:  92
# Source loss:  0.1343172  Source acc:  0.96875
# Target loss:  0.15659216  Target acc:  1.0
# Epoch:  2  Batch:  93
# Source loss:  0.014332524  Source acc:  1.0
# Target loss:  0.174889  Target acc:  0.984375
# Epoch:  2  Batch:  94
# Source loss:  0.003457461  Source acc:  1.0
# Target loss:  0.15706235  Target acc:  1.0
# Epoch:  2  Batch:  95
# Source loss:  0.002850051  Source acc:  1.0
# Target loss:  0.15676884  Target acc:  1.0
# Epoch:  2  Batch:  96
# Source loss:  0.004463328  Source acc:  1.0
# Target loss:  0.15733401  Target acc:  1.0
# Epoch:  2  Batch:  97
# Source loss:  0.010255232  Source acc:  1.0
# Target loss:  0.17224303  Target acc:  1.0
# Epoch:  2  Batch:  98
# Source loss:  0.027515255  Source acc:  0.984375
# Target loss:  0.16026685  Target acc:  1.0
# Epoch:  2  Batch:  99
# Source loss:  0.03537241  Source acc:  0.984375
# Target loss:  0.1566396  Target acc:  1.0
# Epoch:  2  Batch:  100
# Source loss:  0.0036680594  Source acc:  1.0
# Target loss:  0.15667675  Target acc:  1.0
# Epoch:  2  Batch:  101
# Source loss:  0.014612121  Source acc:  1.0
# Target loss:  0.15672001  Target acc:  1.0
# Epoch:  2  Batch:  102
# Source loss:  0.017868048  Source acc:  1.0
# Target loss:  0.15680413  Target acc:  1.0
# Epoch:  2  Batch:  103
# Source loss:  0.12133008  Source acc:  0.953125
# Target loss:  0.15764345  Target acc:  1.0
# Epoch:  2  Batch:  104
# Source loss:  0.030866798  Source acc:  0.984375
# Target loss:  0.15670572  Target acc:  1.0
# Epoch:  2  Batch:  105
# Source loss:  0.0374042  Source acc:  1.0
# Target loss:  0.20698541  Target acc:  0.984375
# Epoch:  2  Batch:  106
# Source loss:  0.022011623  Source acc:  0.984375
# Target loss:  0.16473003  Target acc:  1.0
# Epoch:  2  Batch:  107
# Source loss:  0.16929615  Source acc:  0.96875
# Target loss:  0.24641398  Target acc:  0.984375
# Epoch:  2  Batch:  108
# Source loss:  0.053228218  Source acc:  0.984375
# Target loss:  0.15861925  Target acc:  1.0
# Epoch:  2  Batch:  109
# Source loss:  0.062149875  Source acc:  0.984375
# Target loss:  0.20725822  Target acc:  0.984375
# Epoch:  2  Batch:  110
# Source loss:  0.008333417  Source acc:  1.0
# Target loss:  0.15742688  Target acc:  1.0
# Epoch:  2  Batch:  111
# Source loss:  0.0539159  Source acc:  0.984375
# Target loss:  0.15635748  Target acc:  1.0
# Epoch:  2  Batch:  112
# Source loss:  0.0077688424  Source acc:  1.0
# Target loss:  0.17541647  Target acc:  0.984375
# Epoch:  3  Batch:  0
# Source loss:  0.0069410065  Source acc:  1.0
# Target loss:  0.15856588  Target acc:  1.0
# Epoch:  3  Batch:  1
# Source loss:  0.041242145  Source acc:  0.984375
# Target loss:  0.15967949  Target acc:  1.0
# Epoch:  3  Batch:  2
# Source loss:  0.059344623  Source acc:  0.984375
# Target loss:  0.15685305  Target acc:  1.0
# Epoch:  3  Batch:  3
# Source loss:  0.0322426  Source acc:  0.96875
# Target loss:  0.15717356  Target acc:  1.0
# Epoch:  3  Batch:  4
# Source loss:  0.0065404037  Source acc:  1.0
# Target loss:  0.15706845  Target acc:  1.0
# Epoch:  3  Batch:  5
# Source loss:  0.053292572  Source acc:  0.984375
# Target loss:  0.16005999  Target acc:  1.0
# Epoch:  3  Batch:  6
# Source loss:  0.07823772  Source acc:  0.96875
# Target loss:  0.15709035  Target acc:  1.0
# Epoch:  3  Batch:  7
# Source loss:  0.021567795  Source acc:  1.0
# Target loss:  0.15642303  Target acc:  1.0
# Epoch:  3  Batch:  8
# Source loss:  0.05617466  Source acc:  0.984375
# Target loss:  0.15843572  Target acc:  1.0
# Epoch:  3  Batch:  9
# Source loss:  0.031150993  Source acc:  1.0
# Target loss:  0.16129223  Target acc:  1.0
# Epoch:  3  Batch:  10
# Source loss:  0.03067689  Source acc:  1.0
# Target loss:  0.15755023  Target acc:  1.0
# Epoch:  3  Batch:  11
# Source loss:  0.074073546  Source acc:  0.953125
# Target loss:  0.15674184  Target acc:  1.0
# Epoch:  3  Batch:  12
# Source loss:  0.10058098  Source acc:  0.96875
# Target loss:  0.15891531  Target acc:  1.0
# Epoch:  3  Batch:  13
# Source loss:  0.16282119  Source acc:  0.96875
# Target loss:  0.16174415  Target acc:  1.0
# Epoch:  3  Batch:  14
# Source loss:  0.0070642587  Source acc:  1.0
# Target loss:  0.16059461  Target acc:  1.0
# Epoch:  3  Batch:  15
# Source loss:  0.12024443  Source acc:  0.96875
# Target loss:  0.16408508  Target acc:  1.0
# Epoch:  3  Batch:  16
# Source loss:  0.008458028  Source acc:  1.0
# Target loss:  0.15733494  Target acc:  1.0
# Epoch:  3  Batch:  17
# Source loss:  0.007917629  Source acc:  1.0
# Target loss:  0.15702724  Target acc:  1.0
# Epoch:  3  Batch:  18
# Source loss:  0.008158231  Source acc:  1.0
# Target loss:  0.15677465  Target acc:  1.0
# Epoch:  3  Batch:  19
# Source loss:  0.035098203  Source acc:  0.984375
# Target loss:  0.15695415  Target acc:  1.0
# Epoch:  3  Batch:  20
# Source loss:  0.060093008  Source acc:  0.984375
# Target loss:  0.15724511  Target acc:  1.0
# Epoch:  3  Batch:  21
# Source loss:  0.039726757  Source acc:  0.984375
# Target loss:  0.15709892  Target acc:  1.0
# Epoch:  3  Batch:  22
# Source loss:  0.047695454  Source acc:  0.984375
# Target loss:  0.15794922  Target acc:  1.0
# Epoch:  3  Batch:  23
# Source loss:  0.13215576  Source acc:  0.96875
# Target loss:  0.15569623  Target acc:  1.0
# Epoch:  3  Batch:  24
# Source loss:  0.0225004  Source acc:  1.0
# Target loss:  0.15759441  Target acc:  1.0
# Epoch:  3  Batch:  25
# Source loss:  0.28140408  Source acc:  0.9375
# Target loss:  0.16035758  Target acc:  1.0
# Epoch:  3  Batch:  26
# Source loss:  0.0066598016  Source acc:  1.0
# Target loss:  0.15817882  Target acc:  1.0
# Epoch:  3  Batch:  27
# Source loss:  0.042221714  Source acc:  0.984375
# Target loss:  0.1634046  Target acc:  1.0
# Epoch:  3  Batch:  28
# Source loss:  0.07880294  Source acc:  0.984375
# Target loss:  0.15815735  Target acc:  1.0
# Epoch:  3  Batch:  29
# Source loss:  0.079984784  Source acc:  0.96875
# Target loss:  0.15631786  Target acc:  1.0
# Epoch:  3  Batch:  30
# Source loss:  0.10977847  Source acc:  0.96875
# Target loss:  0.15723139  Target acc:  1.0
# Epoch:  3  Batch:  31
# Source loss:  0.008910995  Source acc:  1.0
# Target loss:  0.15647022  Target acc:  1.0
# Epoch:  3  Batch:  32
# Source loss:  0.058616653  Source acc:  0.984375
# Target loss:  0.15655695  Target acc:  1.0
# Epoch:  3  Batch:  33
# Source loss:  0.071367964  Source acc:  0.984375
# Target loss:  0.15984215  Target acc:  1.0
# Epoch:  3  Batch:  34
# Source loss:  0.0053425254  Source acc:  1.0
# Target loss:  0.1579663  Target acc:  1.0
# Epoch:  3  Batch:  35
# Source loss:  0.033138417  Source acc:  0.984375
# Target loss:  0.15777297  Target acc:  1.0
# Epoch:  3  Batch:  36
# Source loss:  0.015778868  Source acc:  1.0
# Target loss:  0.15690307  Target acc:  1.0
# Epoch:  3  Batch:  37
# Source loss:  0.016826274  Source acc:  0.984375
# Target loss:  0.15809433  Target acc:  1.0
# Epoch:  3  Batch:  38
# Source loss:  0.036229327  Source acc:  0.984375
# Target loss:  0.15693484  Target acc:  1.0
# Epoch:  3  Batch:  39
# Source loss:  0.01063307  Source acc:  1.0
# Target loss:  0.15877679  Target acc:  1.0
# Epoch:  3  Batch:  40
# Source loss:  0.046649944  Source acc:  0.984375
# Target loss:  0.15681008  Target acc:  1.0
# Epoch:  3  Batch:  41
# Source loss:  0.054360997  Source acc:  0.96875
# Target loss:  0.15584989  Target acc:  1.0
# Epoch:  3  Batch:  42
# Source loss:  0.046708647  Source acc:  0.984375
# Target loss:  0.1568726  Target acc:  1.0
# Epoch:  3  Batch:  43
# Source loss:  0.11957213  Source acc:  0.96875
# Target loss:  0.15671846  Target acc:  1.0
# Epoch:  3  Batch:  44
# Source loss:  0.010568754  Source acc:  1.0
# Target loss:  0.15750113  Target acc:  1.0
# Epoch:  3  Batch:  45
# Source loss:  0.0035572718  Source acc:  1.0
# Target loss:  0.15654351  Target acc:  1.0
# Epoch:  3  Batch:  46
# Source loss:  0.13609855  Source acc:  0.96875
# Target loss:  0.15985581  Target acc:  1.0
# Epoch:  3  Batch:  47
# Source loss:  0.015722644  Source acc:  0.984375
# Target loss:  0.15650377  Target acc:  1.0
# Epoch:  3  Batch:  48
# Source loss:  0.0010819521  Source acc:  1.0
# Target loss:  0.15742896  Target acc:  1.0
# Epoch:  3  Batch:  49
# Source loss:  0.0051599666  Source acc:  1.0
# Target loss:  0.16189547  Target acc:  1.0
# Epoch:  3  Batch:  50
# Source loss:  0.011467587  Source acc:  1.0
# Target loss:  0.1575695  Target acc:  1.0
# Epoch:  3  Batch:  51
# Source loss:  0.009597922  Source acc:  1.0
# Target loss:  0.15672366  Target acc:  1.0
# Epoch:  3  Batch:  52
# Source loss:  0.058076978  Source acc:  0.96875
# Target loss:  0.15815991  Target acc:  1.0
# Epoch:  3  Batch:  53
# Source loss:  0.09703658  Source acc:  0.96875
# Target loss:  0.1577266  Target acc:  1.0
# Epoch:  3  Batch:  54
# Source loss:  0.0045763096  Source acc:  1.0
# Target loss:  0.16308686  Target acc:  1.0
# Epoch:  3  Batch:  55
# Source loss:  0.051058393  Source acc:  0.984375
# Target loss:  0.1572628  Target acc:  1.0
# Epoch:  3  Batch:  56
# Source loss:  0.027250998  Source acc:  0.984375
# Target loss:  0.15586199  Target acc:  1.0
# Epoch:  3  Batch:  57
# Source loss:  0.014477743  Source acc:  1.0
# Target loss:  0.15963978  Target acc:  1.0
# Epoch:  3  Batch:  58
# Source loss:  0.0017223328  Source acc:  1.0
# Target loss:  0.15764745  Target acc:  1.0
# Epoch:  3  Batch:  59
# Source loss:  0.08092481  Source acc:  0.96875
# Target loss:  0.15713087  Target acc:  1.0
# Epoch:  3  Batch:  60
# Source loss:  0.023420183  Source acc:  0.984375
# Target loss:  0.1567618  Target acc:  1.0
# Epoch:  3  Batch:  61
# Source loss:  0.0021974999  Source acc:  1.0
# Target loss:  0.15676029  Target acc:  1.0
# Epoch:  3  Batch:  62
# Source loss:  0.0034510125  Source acc:  1.0
# Target loss:  0.15610905  Target acc:  1.0
# Epoch:  3  Batch:  63
# Source loss:  0.109368876  Source acc:  0.984375
# Target loss:  0.15663588  Target acc:  1.0
# Epoch:  3  Batch:  64
# Source loss:  0.015863  Source acc:  1.0
# Target loss:  0.15715642  Target acc:  1.0
# Epoch:  3  Batch:  65
# Source loss:  0.0030549357  Source acc:  1.0
# Target loss:  0.15662071  Target acc:  1.0
# Epoch:  3  Batch:  66
# Source loss:  0.021495346  Source acc:  0.984375
# Target loss:  0.15631296  Target acc:  1.0
# Epoch:  3  Batch:  67
# Source loss:  0.2447004  Source acc:  0.984375
# Target loss:  0.15689467  Target acc:  1.0
# Epoch:  3  Batch:  68
# Source loss:  0.084377915  Source acc:  0.96875
# Target loss:  0.15682434  Target acc:  1.0
# Epoch:  3  Batch:  69
# Source loss:  0.002278453  Source acc:  1.0
# Target loss:  0.15946856  Target acc:  1.0
# Epoch:  3  Batch:  70
# Source loss:  0.013613164  Source acc:  1.0
# Target loss:  0.15660903  Target acc:  1.0
# Epoch:  3  Batch:  71
# Source loss:  0.0015991353  Source acc:  1.0
# Target loss:  0.16036575  Target acc:  1.0
# Epoch:  3  Batch:  72
# Source loss:  0.05443607  Source acc:  0.96875
# Target loss:  0.15793122  Target acc:  1.0
# Epoch:  3  Batch:  73
# Source loss:  0.014236841  Source acc:  1.0
# Target loss:  0.15650637  Target acc:  1.0
# Epoch:  3  Batch:  74
# Source loss:  0.0067407712  Source acc:  1.0
# Target loss:  0.15702835  Target acc:  1.0
# Epoch:  3  Batch:  75
# Source loss:  0.08693982  Source acc:  0.984375
# Target loss:  0.15570456  Target acc:  1.0
# Epoch:  3  Batch:  76
# Source loss:  0.06909571  Source acc:  0.984375
# Target loss:  0.15673602  Target acc:  1.0
# Epoch:  3  Batch:  77
# Source loss:  0.013187102  Source acc:  1.0
# Target loss:  0.15649809  Target acc:  1.0
# Epoch:  3  Batch:  78
# Source loss:  0.02352867  Source acc:  0.984375
# Target loss:  0.15637177  Target acc:  1.0
# Epoch:  3  Batch:  79
# Source loss:  0.01290244  Source acc:  0.984375
# Target loss:  0.15898429  Target acc:  1.0
# Epoch:  3  Batch:  80
# Source loss:  0.0374761  Source acc:  0.984375
# Target loss:  0.15651238  Target acc:  1.0
# Epoch:  3  Batch:  81
# Source loss:  0.005337124  Source acc:  1.0
# Target loss:  0.15688248  Target acc:  1.0
# Epoch:  3  Batch:  82
# Source loss:  0.08777666  Source acc:  0.96875
# Target loss:  0.15978068  Target acc:  1.0
# Epoch:  3  Batch:  83
# Source loss:  0.06586008  Source acc:  0.984375
# Target loss:  0.1584916  Target acc:  1.0
# Epoch:  3  Batch:  84
# Source loss:  0.041404955  Source acc:  0.984375
# Target loss:  0.15562652  Target acc:  1.0
# Epoch:  3  Batch:  85
# Source loss:  0.00084442785  Source acc:  1.0
# Target loss:  0.1563977  Target acc:  1.0
# Epoch:  3  Batch:  86
# Source loss:  0.00060315256  Source acc:  1.0
# Target loss:  0.15614328  Target acc:  1.0
# Epoch:  3  Batch:  87
# Source loss:  0.0044943136  Source acc:  1.0
# Target loss:  0.15706472  Target acc:  1.0
# Epoch:  3  Batch:  88
# ...
# Target loss:  0.15605591  Target acc:  1.0
# Epoch:  28  Batch:  84
# Source loss:  0.040724143  Source acc:  0.984375
# Target loss:  0.1567812  Target acc:  1.0
# Epoch:  28  Batch:  85
# Source loss:  0.043544907  Source acc:  0.984375
# Target loss:  0.15597847  Target acc:  1.0
# Epoch:  28  Batch:  86
# Source loss:  0.034344144  Source acc:  0.984375
# Target loss:  0.15623663  Target acc:  1.0
# Epoch:  28  Batch:  87
# Source loss:  0.17282273  Source acc:  0.9375
# Target loss:  0.15646012  Target acc:  1.0
# Epoch:  28  Batch:  88
# Source loss:  0.1495532  Source acc:  0.96875
# Target loss:  0.15554604  Target acc:  1.0
# Epoch:  28  Batch:  89
# Source loss:  0.24208969  Source acc:  0.953125
# Target loss:  0.15623014  Target acc:  1.0
# Epoch:  28  Batch:  90
# Source loss:  0.0018585303  Source acc:  1.0
# Target loss:  0.15656045  Target acc:  1.0
# Epoch:  28  Batch:  91
# Source loss:  0.01044303  Source acc:  1.0
# Target loss:  0.1552811  Target acc:  1.0
# Epoch:  28  Batch:  92
# Source loss:  0.112693116  Source acc:  0.984375
# Target loss:  0.15641494  Target acc:  1.0
# Epoch:  28  Batch:  93
# Source loss:  0.102992274  Source acc:  0.984375
# Target loss:  0.15647879  Target acc:  1.0
# Epoch:  28  Batch:  94
# Source loss:  0.056899417  Source acc:  0.96875
# Target loss:  0.15663332  Target acc:  1.0
# Epoch:  28  Batch:  95
# Source loss:  0.07100504  Source acc:  0.96875
# Target loss:  0.16527066  Target acc:  1.0
# Epoch:  28  Batch:  96
# Source loss:  0.0010135805  Source acc:  1.0
# Target loss:  0.15588935  Target acc:  1.0
# Epoch:  28  Batch:  97
# Source loss:  0.030813659  Source acc:  1.0
# Target loss:  0.15640122  Target acc:  1.0
# Epoch:  28  Batch:  98
# Source loss:  0.039751966  Source acc:  0.984375
# Target loss:  0.15638383  Target acc:  1.0
# Epoch:  28  Batch:  99
# Source loss:  0.0012315605  Source acc:  1.0
# Target loss:  0.15667036  Target acc:  1.0
# Epoch:  28  Batch:  100
# Source loss:  0.016101565  Source acc:  1.0
# Target loss:  0.15752783  Target acc:  1.0
# Epoch:  28  Batch:  101
# Source loss:  0.039654635  Source acc:  1.0
# Target loss:  0.15630588  Target acc:  1.0
# Epoch:  28  Batch:  102
# Source loss:  0.067265406  Source acc:  0.984375
# Target loss:  0.15632439  Target acc:  1.0
# Epoch:  28  Batch:  103
# Source loss:  0.038527064  Source acc:  0.984375
# Target loss:  0.15648  Target acc:  1.0
# Epoch:  28  Batch:  104
# Source loss:  0.038651615  Source acc:  0.96875
# Target loss:  0.15653852  Target acc:  1.0
# Epoch:  28  Batch:  105
# Source loss:  0.021374278  Source acc:  0.984375
# Target loss:  0.15639563  Target acc:  1.0
# Epoch:  28  Batch:  106
# Source loss:  0.0023265008  Source acc:  1.0
# Target loss:  0.15654095  Target acc:  1.0
# Epoch:  28  Batch:  107
# Source loss:  0.08113611  Source acc:  0.96875
# Target loss:  0.16136003  Target acc:  1.0
# Epoch:  28  Batch:  108
# Source loss:  0.02040806  Source acc:  1.0
# Target loss:  0.15649636  Target acc:  1.0
# Epoch:  28  Batch:  109
# Source loss:  0.013562806  Source acc:  1.0
# Target loss:  0.15627229  Target acc:  1.0
# Epoch:  28  Batch:  110
# Source loss:  0.02014712  Source acc:  0.984375
# Target loss:  0.15638024  Target acc:  1.0
# Epoch:  28  Batch:  111
# Source loss:  0.041164447  Source acc:  0.984375
# Target loss:  0.15641281  Target acc:  1.0
# Epoch:  28  Batch:  112
# Source loss:  0.042435776  Source acc:  0.984375
# Target loss:  0.15749012  Target acc:  1.0
# Epoch:  29  Batch:  0
# Source loss:  0.021594988  Source acc:  1.0
# Target loss:  0.15658484  Target acc:  1.0
# Epoch:  29  Batch:  1
# Source loss:  0.002147733  Source acc:  1.0
# Target loss:  0.15667552  Target acc:  1.0
# Epoch:  29  Batch:  2
# Source loss:  0.2015727  Source acc:  0.96875
# Target loss:  0.15620996  Target acc:  1.0
# Epoch:  29  Batch:  3
# Source loss:  0.0012897208  Source acc:  1.0
# Target loss:  0.1562693  Target acc:  1.0
# Epoch:  29  Batch:  4
# Source loss:  0.011178859  Source acc:  1.0
# Target loss:  0.15727058  Target acc:  1.0
# Epoch:  29  Batch:  5
# Source loss:  0.001892199  Source acc:  1.0
# Target loss:  0.15633102  Target acc:  1.0
# Epoch:  29  Batch:  6
# Source loss:  0.14927474  Source acc:  0.953125
# Target loss:  0.15639596  Target acc:  1.0
# Epoch:  29  Batch:  7
# Source loss:  0.047232676  Source acc:  0.984375
# Target loss:  0.15714909  Target acc:  1.0
# Epoch:  29  Batch:  8
# Source loss:  0.07085101  Source acc:  0.96875
# Target loss:  0.23559639  Target acc:  0.984375
# Epoch:  29  Batch:  9
# Source loss:  0.002197085  Source acc:  1.0
# Target loss:  0.15594712  Target acc:  1.0
# Epoch:  29  Batch:  10
# Source loss:  0.00850403  Source acc:  1.0
# Target loss:  0.15667336  Target acc:  1.0
# Epoch:  29  Batch:  11
# Source loss:  0.021259626  Source acc:  0.984375
# Target loss:  0.15651888  Target acc:  1.0
# Epoch:  29  Batch:  12
# Source loss:  0.16203175  Source acc:  0.96875
# Target loss:  0.15606597  Target acc:  1.0
# Epoch:  29  Batch:  13
# Source loss:  0.018710878  Source acc:  0.984375
# Target loss:  0.15629351  Target acc:  1.0
# Epoch:  29  Batch:  14
# Source loss:  0.006973185  Source acc:  1.0
# Target loss:  0.15676163  Target acc:  1.0
# Epoch:  29  Batch:  15
# Source loss:  0.06850339  Source acc:  0.984375
# Target loss:  0.15634221  Target acc:  1.0
# Epoch:  29  Batch:  16
# Source loss:  0.06539231  Source acc:  0.96875
# Target loss:  0.15653798  Target acc:  1.0
# Epoch:  29  Batch:  17
# Source loss:  0.017861962  Source acc:  0.984375
# Target loss:  0.15623404  Target acc:  1.0
# Epoch:  29  Batch:  18
# Source loss:  0.008441547  Source acc:  1.0
# Target loss:  0.15621611  Target acc:  1.0
# Epoch:  29  Batch:  19
# Source loss:  0.07222799  Source acc:  0.984375
# Target loss:  0.1557209  Target acc:  1.0
# Epoch:  29  Batch:  20
# Source loss:  0.01362345  Source acc:  1.0
# Target loss:  0.15617494  Target acc:  1.0
# Epoch:  29  Batch:  21
# Source loss:  0.03508301  Source acc:  0.984375
# Target loss:  0.1584045  Target acc:  1.0
# Epoch:  29  Batch:  22
# Source loss:  0.0035425788  Source acc:  1.0
# Target loss:  0.1568333  Target acc:  1.0
# Epoch:  29  Batch:  23
# Source loss:  0.0050466075  Source acc:  1.0
# Target loss:  0.15613917  Target acc:  1.0
# Epoch:  29  Batch:  24
# Source loss:  0.0060776053  Source acc:  1.0
# Target loss:  0.15634696  Target acc:  1.0
# Epoch:  29  Batch:  25
# Source loss:  0.03141791  Source acc:  1.0
# Target loss:  0.1569987  Target acc:  1.0
# Epoch:  29  Batch:  26
# Source loss:  0.0033720308  Source acc:  1.0
# Target loss:  0.1559461  Target acc:  1.0
# Epoch:  29  Batch:  27
# Source loss:  0.048447732  Source acc:  0.984375
# Target loss:  0.15671468  Target acc:  1.0
# Epoch:  29  Batch:  28
# Source loss:  0.024638193  Source acc:  1.0
# Target loss:  0.15629284  Target acc:  1.0
# Epoch:  29  Batch:  29
# Source loss:  0.012240335  Source acc:  1.0
# Target loss:  0.15566237  Target acc:  1.0
# Epoch:  29  Batch:  30
# Source loss:  0.005768972  Source acc:  1.0
# Target loss:  0.15731046  Target acc:  1.0
# Epoch:  29  Batch:  31
# Source loss:  0.06494245  Source acc:  0.984375
# Target loss:  0.15688369  Target acc:  1.0
# Epoch:  29  Batch:  32
# Source loss:  0.07474901  Source acc:  0.96875
# Target loss:  0.15638715  Target acc:  1.0
# Epoch:  29  Batch:  33
# Source loss:  0.035273984  Source acc:  1.0
# Target loss:  0.1571818  Target acc:  1.0
# Epoch:  29  Batch:  34
# Source loss:  0.04210627  Source acc:  0.984375
# Target loss:  0.15682898  Target acc:  1.0
# Epoch:  29  Batch:  35
# Source loss:  0.04448093  Source acc:  0.96875
# Target loss:  0.1565292  Target acc:  1.0
# Epoch:  29  Batch:  36
# Source loss:  0.0015158651  Source acc:  1.0
# Target loss:  0.15640613  Target acc:  1.0
# Epoch:  29  Batch:  37
# Source loss:  0.0027798736  Source acc:  1.0
# Target loss:  0.15644567  Target acc:  1.0
# Epoch:  29  Batch:  38
# Source loss:  0.00569073  Source acc:  1.0
# Target loss:  0.15601318  Target acc:  1.0
# Epoch:  29  Batch:  39
# Source loss:  0.005352379  Source acc:  1.0
# Target loss:  0.15735923  Target acc:  1.0
# Epoch:  29  Batch:  40
# Source loss:  0.0014363709  Source acc:  1.0
# Target loss:  0.15639794  Target acc:  1.0
# Epoch:  29  Batch:  41
# Source loss:  0.0059094313  Source acc:  1.0
# Target loss:  0.15622965  Target acc:  1.0
# Epoch:  29  Batch:  42
# Source loss:  0.093346804  Source acc:  0.96875
# Target loss:  0.15693256  Target acc:  1.0
# Epoch:  29  Batch:  43
# Source loss:  0.0025148967  Source acc:  1.0
# Target loss:  0.15664741  Target acc:  1.0
# Epoch:  29  Batch:  44
# Source loss:  0.010196799  Source acc:  1.0
# Target loss:  0.1566552  Target acc:  1.0
# Epoch:  29  Batch:  45
# Source loss:  0.11103948  Source acc:  0.984375
# Target loss:  0.15604801  Target acc:  1.0
# Epoch:  29  Batch:  46
# Source loss:  0.0031032334  Source acc:  1.0
# Target loss:  0.15729658  Target acc:  1.0
# Epoch:  29  Batch:  47
# Source loss:  0.0024344425  Source acc:  1.0
# Target loss:  0.15699176  Target acc:  1.0
# Epoch:  29  Batch:  48
# Source loss:  0.034247436  Source acc:  0.984375
# Target loss:  0.15672778  Target acc:  1.0
# Epoch:  29  Batch:  49
# Source loss:  0.056594912  Source acc:  0.984375
# Target loss:  0.15723665  Target acc:  1.0
# Epoch:  29  Batch:  50
# Source loss:  0.018462095  Source acc:  1.0
# Target loss:  0.15737513  Target acc:  1.0
# Epoch:  29  Batch:  51
# Source loss:  0.044647165  Source acc:  0.984375
# Target loss:  0.15635338  Target acc:  1.0
# Epoch:  29  Batch:  52
# Source loss:  0.013316203  Source acc:  1.0
# Target loss:  0.15656018  Target acc:  1.0
# Epoch:  29  Batch:  53
# Source loss:  0.029362116  Source acc:  0.984375
# Target loss:  0.15631627  Target acc:  1.0
# Epoch:  29  Batch:  54
# Source loss:  0.111425474  Source acc:  0.984375
# Target loss:  0.1561359  Target acc:  1.0
# Epoch:  29  Batch:  55
# Source loss:  0.0007619974  Source acc:  1.0
# Target loss:  0.15613082  Target acc:  1.0
# Epoch:  29  Batch:  56
# Source loss:  0.024857849  Source acc:  0.984375
# Target loss:  0.155629  Target acc:  1.0
# Epoch:  29  Batch:  57
# Source loss:  0.0070084212  Source acc:  1.0
# Target loss:  0.15658483  Target acc:  1.0
# Epoch:  29  Batch:  58
# Source loss:  0.0016171739  Source acc:  1.0
# Target loss:  0.15633488  Target acc:  1.0
# Epoch:  29  Batch:  59
# Source loss:  0.019342307  Source acc:  0.984375
# Target loss:  0.15643704  Target acc:  1.0
# Epoch:  29  Batch:  60
# Source loss:  0.046266463  Source acc:  0.984375
# Target loss:  0.15706165  Target acc:  1.0
# Epoch:  29  Batch:  61
# Source loss:  0.03413744  Source acc:  0.984375
# Target loss:  0.15618595  Target acc:  1.0
# Epoch:  29  Batch:  62
# Source loss:  0.0016623696  Source acc:  1.0
# Target loss:  0.15580034  Target acc:  1.0
# Epoch:  29  Batch:  63
# Source loss:  0.008939807  Source acc:  1.0
# Target loss:  0.16385403  Target acc:  1.0
# Epoch:  29  Batch:  64
# Source loss:  0.026600095  Source acc:  0.984375
# Target loss:  0.1563427  Target acc:  1.0
# Epoch:  29  Batch:  65
# Source loss:  0.016023621  Source acc:  1.0
# Target loss:  0.15690625  Target acc:  1.0
# Epoch:  29  Batch:  66
# Source loss:  0.004403213  Source acc:  1.0
# Target loss:  0.15675394  Target acc:  1.0
# Epoch:  29  Batch:  67
# Source loss:  0.09507494  Source acc:  0.96875
# Target loss:  0.15607022  Target acc:  1.0
# Epoch:  29  Batch:  68
# Source loss:  0.012799376  Source acc:  0.984375
# Target loss:  0.15778455  Target acc:  1.0
# Epoch:  29  Batch:  69
# Source loss:  0.054516163  Source acc:  0.984375
# Target loss:  0.1567173  Target acc:  1.0
# Epoch:  29  Batch:  70
# Source loss:  0.07638052  Source acc:  0.984375
# Target loss:  0.15639022  Target acc:  1.0
# Epoch:  29  Batch:  71
# Source loss:  0.041686025  Source acc:  0.984375
# Target loss:  0.15627334  Target acc:  1.0
# Epoch:  29  Batch:  72
# Source loss:  0.13620523  Source acc:  0.96875
# Target loss:  0.15635784  Target acc:  1.0
# Epoch:  29  Batch:  73
# Source loss:  0.024696972  Source acc:  0.984375
# Target loss:  0.1574934  Target acc:  1.0
# Epoch:  29  Batch:  74
# Source loss:  0.0007142773  Source acc:  1.0
# Target loss:  0.15648985  Target acc:  1.0
# Epoch:  29  Batch:  75
# Source loss:  0.020401103  Source acc:  0.984375
# Target loss:  0.1565092  Target acc:  1.0
# Epoch:  29  Batch:  76
# Source loss:  0.034714118  Source acc:  0.984375
# Target loss:  0.15703161  Target acc:  1.0
# Epoch:  29  Batch:  77
# Source loss:  0.07341511  Source acc:  0.984375
# Target loss:  0.15642153  Target acc:  1.0
# Epoch:  29  Batch:  78
# Source loss:  0.06397992  Source acc:  0.96875
# Target loss:  0.15624358  Target acc:  1.0
# Epoch:  29  Batch:  79
# Source loss:  0.0010966094  Source acc:  1.0
# Target loss:  0.15565443  Target acc:  1.0
# Epoch:  29  Batch:  80
# Source loss:  0.00819678  Source acc:  1.0
# Target loss:  0.15622836  Target acc:  1.0
# Epoch:  29  Batch:  81
# Source loss:  0.00061093655  Source acc:  1.0
# Target loss:  0.1567627  Target acc:  1.0
# Epoch:  29  Batch:  82
# Source loss:  0.0137812765  Source acc:  1.0
# Target loss:  0.15691002  Target acc:  1.0
# Epoch:  29  Batch:  83
# Source loss:  0.14329363  Source acc:  0.984375
# Target loss:  0.15615161  Target acc:  1.0
# Epoch:  29  Batch:  84
# Source loss:  0.020711284  Source acc:  0.984375
# Target loss:  0.15619877  Target acc:  1.0
# Epoch:  29  Batch:  85
# Source loss:  0.0008791352  Source acc:  1.0
# Target loss:  0.15621853  Target acc:  1.0
# Epoch:  29  Batch:  86
# Source loss:  0.04316104  Source acc:  0.984375
# Target loss:  0.1567129  Target acc:  1.0
# Epoch:  29  Batch:  87
# Source loss:  0.006880227  Source acc:  1.0
# Target loss:  0.15692282  Target acc:  1.0
# Epoch:  29  Batch:  88
# Source loss:  0.0033861257  Source acc:  1.0
# Target loss:  0.15647888  Target acc:  1.0
# Epoch:  29  Batch:  89
# Source loss:  0.00046112435  Source acc:  1.0
# Target loss:  0.15660356  Target acc:  1.0
# Epoch:  29  Batch:  90
# Source loss:  0.051356554  Source acc:  0.96875
# Target loss:  0.15611535  Target acc:  1.0
# Epoch:  29  Batch:  91
# Source loss:  0.012778925  Source acc:  1.0
# Target loss:  0.1562469  Target acc:  1.0
# Epoch:  29  Batch:  92
# Source loss:  0.012162911  Source acc:  1.0
# Target loss:  0.1563246  Target acc:  1.0
# Epoch:  29  Batch:  93
# Source loss:  0.017237429  Source acc:  0.984375
# Target loss:  0.15683569  Target acc:  1.0
# Epoch:  29  Batch:  94
# Source loss:  0.050044145  Source acc:  0.984375
# Target loss:  0.15653807  Target acc:  1.0
# Epoch:  29  Batch:  95
# Source loss:  0.10488062  Source acc:  0.96875
# Target loss:  0.15687597  Target acc:  1.0
# Epoch:  29  Batch:  96
# Source loss:  0.022346077  Source acc:  0.984375
# Target loss:  0.15671848  Target acc:  1.0
# Epoch:  29  Batch:  97
# Source loss:  0.001843296  Source acc:  1.0
# Target loss:  0.1561325  Target acc:  1.0
# Epoch:  29  Batch:  98
# Source loss:  0.009758832  Source acc:  1.0
# Target loss:  0.15626149  Target acc:  1.0
# Epoch:  29  Batch:  99
# Source loss:  0.024245394  Source acc:  0.984375
# Target loss:  0.15756449  Target acc:  1.0
# Epoch:  29  Batch:  100
# Source loss:  0.014614368  Source acc:  1.0
# Target loss:  0.15623908  Target acc:  1.0
# Epoch:  29  Batch:  101
# Source loss:  0.001110961  Source acc:  1.0
# Target loss:  0.15618557  Target acc:  1.0
# Epoch:  29  Batch:  102
# Source loss:  0.01633388  Source acc:  1.0
# Target loss:  0.15625979  Target acc:  1.0
# Epoch:  29  Batch:  103
# Source loss:  0.008432228  Source acc:  1.0
# Target loss:  0.15665269  Target acc:  1.0
# Epoch:  29  Batch:  104
# Source loss:  0.012022482  Source acc:  1.0
# Target loss:  0.15636393  Target acc:  1.0
# Epoch:  29  Batch:  105
# Source loss:  0.038252864  Source acc:  0.984375
# Target loss:  0.15708597  Target acc:  1.0
# Epoch:  29  Batch:  106
# Source loss:  0.08904863  Source acc:  0.984375
# Target loss:  0.15652263  Target acc:  1.0
# Epoch:  29  Batch:  107
# Source loss:  0.0020478135  Source acc:  1.0
# Target loss:  0.15638162  Target acc:  1.0
# Epoch:  29  Batch:  108
# Source loss:  0.010897995  Source acc:  1.0
# Target loss:  0.15744889  Target acc:  1.0
# Epoch:  29  Batch:  109
# Source loss:  0.061462812  Source acc:  0.96875
# Target loss:  0.1566631  Target acc:  1.0
# Epoch:  29  Batch:  110
# Source loss:  0.016814759  Source acc:  0.984375
# Target loss:  0.1565121  Target acc:  1.0
# Epoch:  29  Batch:  111
# Source loss:  0.015818583  Source acc:  0.984375
# Target loss:  0.1561206  Target acc:  1.0
# Epoch:  29  Batch:  112
# Source loss:  0.1265242  Source acc:  0.984375
# Target loss:  0.1565384  Target acc:  1.0

# %%
model_source.evaluate(target_test_images,target_test_labels)
# Out:
# 2007/2007 [==============================] - 0s 69us/step
# [0.1230525382582817, 0.9740906827296555]

# %%
model_source.evaluate(source_test_images,source_test_labels)
# Out:
# 10000/10000 [==============================] - 1s 70us/step
# [0.04622233961850161, 0.9893]

# %% [markdown]
# ### Save models to disk

# %%
#Source model 
# serialize model to JSON
model_json = model_source.to_json()
with open("model_source.json", "w") as json_file: #GOOD ONE!
    json_file.write(model_json)
# serialize weights to HDF5
model_source.save_weights("model_source.h5")
print("Saved model to disk")

#Target model 
# serialize model to JSON
model_json = model_target.to_json()
with open("model_target.json", "w") as json_file: #GOOD ONE!
    json_file.write(model_json)
# serialize weights to HDF5
model_target.save_weights("model_target.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
# Saved model to disk
